# %%
import numpy as np
import matplotlib.pyplot as plt

BEST_VAL_ERROR = 1.27

# %%
result = np.load("../data/tidy/64_3convlayers.npy")

figure(figsize=(8,6))
test_err = plt.plot(result[0], result[1], 'r', label="Validation error")
train_err =  plt.plot(result[0], result[2], 'b', label="Train error")
plt.xlabel("Gradient step")
plt.ylabel("Negative loglikelyhood")
plt.title("Validation/train error 3 convlayers 64x64 images")
plt.text(19000, 3.6,"Min validation error: %f" % result[1].min())
plt.text(19000, 3.45, "Momentum: 0.9")
plt.text(19000, 3.3, "Learning rate: 0.004")
plt.axhline(BEST_VAL_ERROR, linestyle='--', color='g', label="Best-so-far")
plt.legend()
plt.grid()
plt.show()

# %%
result = np.load("../data/tidy/3convlay_relu_errors.npy")

figure(figsize=(10,8))
test_err = plt.plot(result[0], result[1], 'r', label="Validation error")
train_err =  plt.plot(result[0], result[2], 'b', label="Train error")
plt.ylim([0,5])
plt.xlabel("Gradient step")
plt.ylabel("Negative loglikelyhood")
plt.title("Validation/train error 3 convlayers 48x48 images")
plt.text(32000, 3.8, "Min validation error: %.4f" % result[1].min())
plt.text(32000, 3.65, "Momentum: 0.95")
plt.text(32000, 3.5, "Learning rate: 0.001")
plt.axhline(BEST_VAL_ERROR, linestyle='--', color='g', label="Best-so-far")
plt.legend()
plt.grid()
plt.show()

# %%
result = np.load("../data/tidy/3convlay_relu_errors005.npy")

figure(figsize=(10,8))
test_err = plt.plot(result[0], result[1], 'r', label="Validation error")
train_err =  plt.plot(result[0], result[2], 'b', label="Train error")
plt.ylim([0,5])
plt.xlabel("Gradient step")
plt.ylabel("Negative loglikelyhood")
plt.title("Validation/train error 3 convlayers 48x48 images")
plt.text(26000, 3.8, "Min validation error: %.4f" % result[1].min())
plt.text(26000, 3.65, "Momentum: 0.95")
plt.text(26000, 3.5, "Learning rate: 0.005")
plt.axhline(1.125654, linestyle='--', color='g', label="Best-so-far")
plt.legend()
plt.grid()
plt.show()

# %%
result = np.load("../data/tidy/dense2048_convdropout_errors.npy")

bg

# %%
result = np.load("../data/tidy/dense2048_convdropout_errors.npy")
 
bg_alpha = 0.3
fig = figure(figsize=(10,8))
test_err = plt.plot(result[0], result[1], 'r', label="Validation error")
train_err =  plt.plot(result[0], result[2], 'b', label="Train error")
plt.axvspan(0, 106*400, facecolor='g', alpha=bg_alpha)
plt.axvspan(106*400, 106*700, facecolor='c', alpha=bg_alpha)
plt.axvspan(106*700, 90000, facecolor='y', alpha=bg_alpha)
plt.ylim([0,5])
plt.xlabel("Gradient step")
plt.ylabel("Negative loglikelyhood")
plt.title("Validation/train error dynamic learning rate and momentum")
plt.text(65000, 4.1, "Min validation error: %f" % result[1].min())
plt.text(15000, 0.5, "Momentum: 0.95\nLearning rate: $10^{-3}$")
plt.text(50000, 0.5, "Momentum: 0.99\nLearning rate: $5*10^{-4}$")
plt.text(74550, 0.5, "Momentum: 0.95\nLearning rate: $10^{-4}$")
plt.axhline(1.1256, linestyle='--', color='g', label="Best-so-far")
plt.legend()
plt.grid()
plt.show()

# %%
result = np.load("../data/tidy/maxout2048_convnodropout_errors.npy")

figure(figsize=(10,8))
test_err = plt.plot(result[0], result[1], 'r', label="Validation error")
train_err =  plt.plot(result[0], result[2], 'b', label="Train error")
plt.ylim([0,5])
plt.xlabel("Gradient step")
plt.ylabel("Negative loglikelyhood")
plt.title("Validation/train error 3 convlayers 48x48 images Maxout top layers")
plt.text(18000, 3.8, "Min validation error: %f" % result[1].min())
plt.text(18000, 3.65, "Momentum: 0.95")
plt.text(18000, 3.5, "Learning rate: 0.005")
plt.axhline(BEST_VAL_ERROR, linestyle='--', color='g', label="Best-so-far")
plt.legend()
plt.grid()
plt.show()

# %%
result = np.load("../data/tidy/maxout1024_maxnorm20_errors.npy")

figure(figsize=(10,8))
test_err = plt.plot(result[0], result[1], 'r', label="Validation error")
train_err =  plt.plot(result[0], result[2], 'b', label="Train error")
plt.ylim([0,5])
plt.xlabel("Gradient step")
plt.ylabel("Negative loglikelyhood")
plt.title("Validation/train error 3 convlayers 48x48 images")
plt.text(42000, 3.8, "Min validation error: %f" % result[1].min())
plt.text(42000, 3.65, "Momentum: 0.95")
plt.text(42000, 3.5, "Learning rate: 0.001")
plt.axhline(1.1256, linestyle='--', color='g', label="Best-so-far")
plt.legend()
plt.grid()
plt.show()

# %%
result = np.load("../data/tidy/maxout1024_convdropout01_errors.npy")

figure(figsize=(10,8))
test_err = plt.plot(result[0], result[1], 'r', label="Validation error")
train_err =  plt.plot(result[0], result[2], 'b', label="Train error")
plt.ylim([0,5])
plt.xlabel("Gradient step")
plt.ylabel("Negative loglikelyhood")
plt.title("48x48 images convlayers dropout 0.1")
plt.text(7000, 3.9, "Min validation error: %f" % result[1].min())
plt.text(7000, 3.75, "Momentum: 0.95")
plt.text(7000, 3.6, "Learning rate: 0.001")
plt.axhline(1.1256, linestyle='--', color='g', label="Best-so-far")
plt.legend()
plt.grid()
plt.show()

# %%
result = np.load("../data/tidy/dense2048.npy")

figure(figsize=(10,8))
test_err = plt.plot(result[0], result[1], 'r', label="Validation error")
train_err =  plt.plot(result[0], result[2], 'b', label="Train error")
plt.ylim([0,5])
plt.xlabel("Gradient step")
plt.ylabel("Negative loglikelyhood")
plt.title("48x48 images convlayers dropout 0.1")
plt.text(7000, 3.9, "Min validation error: %f" % result[1].min())
plt.text(7000, 3.75, "Momentum: 0.95")
plt.text(7000, 3.6, "Learning rate: 0.001")
plt.axhline(1.1256, linestyle='--', color='g', label="Best-so-far")
plt.legend()
plt.grid()
plt.show()

# %%
result = np.load("../data/tidy/dense2560_rotation.npy")

figure(figsize=(10,8))
test_err = plt.plot(result[0], result[1], 'r', label="Validation error")
train_err =  plt.plot(result[0], result[2], 'b', label="Train error")
plt.ylim([0,5])
plt.xlabel("Gradient step")
plt.ylabel("Negative loglikelyhood")
plt.title("48x48 images 2560 neurons dense layers")
plt.text(41000, 3.8, "Min validation error: %f" % result[1].min())
plt.text(41000, 3.65, "Momentum: 0.9-0.99")
plt.text(41000, 3.5, "Learning rate: 0.02-0.005")
plt.axhline(1.1256, linestyle='--', color='g', label="Best-so-far")
plt.legend()
plt.grid()
plt.show()

# %%
result = np.load("../data/tidy/49_4convlayers_dense2048_norm01.npy")

figure(figsize=(10,8))
test_err = plt.plot(result[0], result[1], 'r', label="Validation error")
train_err =  plt.plot(result[0], result[2], 'b', label="Train error")
plt.ylim([0,5])
plt.xlabel("Gradient step")
plt.ylabel("Negative loglikelyhood")
plt.title("48x48 images 2048 neurons Maxout layers")
plt.text(490, 3.8, "Min validation error: %f" % result[1].min())
plt.text(490, 3.65, "Momentum: 0.9-0.95")
plt.text(490, 3.5, "Learning rate: 0.02-0.005")
plt.axhline(1.05, linestyle='--', color='g', label="Best-so-far")
plt.legend()
plt.grid()
plt.show()

# %%
result = np.load("../data/tidy/49_4cl_prelu2048_rotations.npy")

figure(figsize=(10,8))
test_err = plt.plot(result[0], result[1], 'r', label="Validation error")
train_err =  plt.plot(result[0], result[2], 'b', label="Train error")
plt.ylim([0,5])
plt.xlabel("Gradient step")
plt.ylabel("Negative loglikelyhood")
plt.title("48x48 images 2048 neurons Maxout layers")
plt.text(490, 3.8, "Min validation error: %f" % result[1].min())
plt.text(490, 3.65, "Momentum: 0.9-0.95")
plt.text(490, 3.5, "Learning rate: 0.02-0.005")
plt.axhline(1.05, linestyle='--', color='g', label="Best-so-far")
plt.legend()
plt.grid()
plt.show()

# %%
result = np.load("../data/tidy/4conv_prelus_maxouts_rotations.npy")
a = np.load("../data/tidy/as.npy")

fig, ax1 = plt.subplots(figsize=(10,8))
test_err = ax1.plot(result[0], result[1], 'r', label="Validation error", linewidth=1.5)
train_err =  ax1.plot(result[0], result[2], 'b', label="Train error", linewidth=1.5)
#ax1.ylim([0,5])
plt.xlabel("Epoch")
ax1.set_ylabel("Negative loglikelyhood")
ax1.axhline(1., linestyle='--', color='g', label="Best-so-far")
ax1.legend()
ax1.text(110, 3.35, "Min validation error: %f" % result[1].min())
ax1.text(110, 3.20, "Momentum: 0.9-0.95")
ax1.text(110, 3.05, "Learning rate: 0.02-0.005")
ax1.grid()
ax1.legend()
# plot a's
ax2 = ax1.twinx()
ax2.plot(result[0], a[1], label="a0", color='lightseagreen')
ax2.plot(result[0], a[2], label="a1", color='seagreen')
ax2.plot(result[0], a[3], label="a2", color='sage')
ax2.plot(result[0], a[4], label="a3", color='darksage')
ax2.set_ylim([-0.4, 1.2])
ax2.legend(loc=2)
plt.title("48x48 images 2048 neurons Maxout layers")
plt.show()

# %%
result = np.load("../data/tidy/48_5cl_prelu2048_rotations_nowd.npy")

figure(figsize=(10,8))
test_err = plt.plot(result[0], result[1], 'r', label="Validation error")
train_err =  plt.plot(result[0], result[2], 'b', label="Train error")
plt.ylim([0,5])
plt.xlabel("Gradient step")
plt.ylabel("Negative loglikelyhood")
plt.title("48x48 images 2048 neurons Maxout layers")
plt.text(160, 3.8, "Min validation error: %f" % result[1].min())
plt.text(160, 3.65, "Momentum: 0.9-0.95")
plt.text(160, 3.5, "Learning rate: 0.02-0.005")
plt.axhline(1.05, linestyle='--', color='g', label="Best-so-far")
plt.legend()
plt.grid()
plt.show()

# %%
result = np.load("../data/tidy/5conv_prelus_maxouts_rotations.npy")

figure(figsize=(10,8))
test_err = plt.plot(result[0], result[1], 'r', label="Validation error")
train_err =  plt.plot(result[0], result[2], 'b', label="Train error")
plt.ylim([0,5])
plt.xlabel("Gradient step")
plt.ylabel("Negative loglikelyhood")
plt.title("48x48 images 2048 neurons Maxout layers")
plt.text(70, 3.8, "Min validation error: %f" % result[1].min())
plt.text(70, 3.65, "Momentum: 0.9-0.95")
plt.text(70, 3.5, "Learning rate: 0.02-0.005")
plt.axhline(1.05, linestyle='--', color='g', label="Best-so-far")
plt.legend()
plt.grid()
plt.show()

# %%
result = np.load("../data/tidy/5conv_prelus_maxouts_rotations.npy")

figure(figsize=(10,8))
test_err = plt.plot(result[0], result[1], 'r', label="Validation error")
train_err =  plt.plot(result[0], result[2], 'b', label="Train error")
plt.ylim([0,5])
plt.xlabel("Gradient step")
plt.ylabel("Negative loglikelyhood")
plt.title("48x48 images 2048 neurons Maxout layers")
plt.text(70, 3.8, "Min validation error: %f" % result[1].min())
plt.text(70, 3.65, "Momentum: 0.9-0.95")
plt.text(70, 3.5, "Learning rate: 0.02-0.005")
plt.axhline(1.05, linestyle='--', color='g', label="Best-so-far")
plt.legend()
plt.grid()
plt.show()

# %%
result = np.load("../data/tidy/5conv_prelus_maxouts768_rotations45.npy")

figure(figsize=(10,8))
test_err = plt.plot(result[0], result[1], 'r', label="Validation error")
train_err =  plt.plot(result[0], result[2], 'b', label="Train error")
plt.ylim([0,5])
plt.xlabel("Gradient step")
plt.ylabel("Negative loglikelyhood")
plt.title("48x48 images 2048 neurons Maxout layers")
plt.text(140, 3.8, "Min validation error: %f" % result[1].min())
plt.text(140, 3.65, "Momentum: 0.9")
plt.text(140, 3.5, "Learning rate: 0.02-0.005")
plt.axhline(1., linestyle='--', color='g', label="Best-so-far")
plt.legend()
plt.grid()
plt.show()

# %%
result = np.load("../data/tidy/5conv_prelus_maxouts768_rotations15.npy")

figure(figsize=(10,8))
test_err = plt.plot(result[0], result[1], 'r', label="Validation error")
train_err =  plt.plot(result[0], result[2], 'b', label="Train error")
plt.ylim([0,5])
plt.xlabel("Gradient step")
plt.ylabel("Negative loglikelyhood")
plt.title("48x48 images 2048 neurons Maxout layers")
plt.text(140, 3.8, "Min validation error: %f" % result[1].min())
plt.text(140, 3.65, "Momentum: 0.9")
plt.text(140, 3.5, "Learning rate: 0.02-0.005")
plt.axhline(1., linestyle='--', color='g', label="Best-so-far")
plt.legend()
plt.grid()
plt.show()

# %%
result = np.load("../data/tidy/5conv_prelus_maxouts768_rotations15_shift4_nopad.npy")

figure(figsize=(10,8))
test_err = plt.plot(result[0], result[1], 'r', label="Validation error")
train_err =  plt.plot(result[0], result[2], 'b', label="Train error")
plt.ylim([0,5])
plt.xlabel("Gradient step")
plt.ylabel("Negative loglikelyhood")
plt.title("48x48 images 2048 neurons Maxout layers")
plt.text(270, 3.8, "Min validation error: %f" % result[1].min())
plt.text(270, 3.65, "Momentum: 0.9")
plt.text(270, 3.5, "Learning rate: 0.02-0.0001")
plt.axhline(1., linestyle='--', color='g', label="Best-so-far")
plt.legend()
plt.grid()
plt.show()

# %%
result = np.load("../data/tidy/5convnpl_prelus_maxouts768_rotations15_shift4_nopad.npy")

figure(figsize=(10,8))
test_err = plt.plot(result[0], result[1], 'r', label="Validation error")
train_err =  plt.plot(result[0], result[2], 'b', label="Train error")
plt.ylim([0,5])
plt.xlabel("Gradient step")
plt.ylabel("Negative loglikelyhood")
plt.title("48x48 images 2048 neurons Maxout layers")
plt.text(270, 3.8, "Min validation error: %f" % result[1].min())
plt.text(270, 3.65, "Momentum: 0.9")
plt.text(270, 3.5, "Learning rate: 0.02-0.0001")
plt.axhline(1., linestyle='--', color='g', label="Best-so-far")
plt.legend()
plt.grid()
plt.show()

# %%
result = np.load("../data/tidy/5convnpl_prelus_maxouts768_rotations15_shift4_nopad_server.npy")

figure(figsize=(10,8))
test_err = plt.plot(result[0], result[1], 'r', label="Validation error")
train_err =  plt.plot(result[0], result[2], 'b', label="Train error")
plt.ylim([0,5])
plt.xlabel("Gradient step")
plt.ylabel("Negative loglikelyhood")
plt.title("48x48 images 2048 neurons Maxout layers")
plt.text(270, 3.8, "Min validation error: %f" % result[1].min())
plt.text(270, 3.65, "Momentum: 0.9")
plt.text(270, 3.5, "Learning rate: 0.02-0.0001")
plt.axhline(1., linestyle='--', color='g', label="Best-so-far")
plt.legend()
plt.grid()
plt.show()
