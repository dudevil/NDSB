# %%
# %cd /home/dudevil/prog/dmlabs/NDSB/

from read_data import DataSetLoader
from zca import ZCA
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import numpy as np
# Out:
# /home/dudevil/prog/dmlabs/NDSB

# %%
dsl = DataSetLoader(rotate_angle=360, n_epochs=5)

# %%
train_x, train_y = dsl.train_gen(augment=True).next()[:]
# Out:
#          1 function calls in 0.000 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}

# %%
train_x.shape
# Out:
# (9000, 2304)

# %%
ind = np.random.randint(9000)
plt.imshow(dsl.X_train_resized[ind].reshape(48,48), cmap=cm.Greys)

# %%
plt.imshow(train_x[ind].reshape(48,48), cmap=cm.Greys)

# %%
# %time dsl.train_gen().next()
# Out:
# CPU times: user 150 ms, sys: 60.1 ms, total: 210 ms
# Wall time: 210 ms
# (array([[ 1.        ,  1.        ,  1.        , ...,  1.        ,
#           1.        ,  1.        ],
#         [ 0.82942706,  0.94791669,  0.94791669, ...,  0.94791669,
#           0.94791669,  0.82942706],
#         [ 0.7972005 ,  0.96875   ,  0.96875   , ...,  0.96875   ,
#           0.96875   ,  0.7972005 ],
#         ...,
#         [ 0.82291669,  0.82291669,  0.82291669, ...,  0.82291669,
#           0.82291669,  0.82291669],
#         [ 1.        ,  1.        ,  1.        , ...,  1.        ,
#           1.        ,  1.        ],
#         [ 0.82855904,  0.86458331,  0.86458331, ...,  0.86458331,
#           0.86458331,  0.82855904]], dtype=float32),
#  array([114,  85,  85, ...,  37,  90,  34], dtype=int32))
