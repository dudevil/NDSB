# %%
# %cd /home/dudevil/prog/dmlabs/NDSB/

from read_data import DataSetLoader
from zca import ZCA
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import numpy as np
# Out:
# /home/dudevil/prog/dmlabs/NDSB
# Using gpu device 0: GeForce GTX 460

# %%
dsl = DataSetLoader(rotate_angle=360, n_epochs=5)

# %%
train_x, train_y = dsl.train_gen(augment=True).next()[:]

# %%
train_x.shape
# Out:
# Exiting
# (27299, 2304)

# %%
ind = np.random.randint(4501)
plt.imshow(dsl.X_train_resized[ind].reshape(48,48), cmap=cm.Greys)

# %%
plt.imshow(train_x[ind].reshape(48,48), cmap=cm.Greys)

# %%
import theano
import theano.tensor as T
from layers import SliceLayer, MergeLayer

batch_size=40

inp = theano.shared(train_x[:batch_size], borrow=True)

x = inp.reshape((batch_size, 1, 48, 48))
sl = SliceLayer(x, (batch_size, 1, 48, 48), out_imgshape=(32,32))
asl = theano.function([], sl.output)
merge = MergeLayer(sl.output, (batch_size * 5, 1,1, 32, 32), 5)
am = theano.function([], merge.output)

plt.imshow(train_x[0].reshape(48,48), cmap=cm.Greys)

# %%
sout = asl()
sout.shape
#plt.imshow(sout.reshape(5* 32,32), cmap=cm.Greys)
# Out:
# (200, 1, 32, 32)

# %%
mout = am()
#plt.imshow(mout.reshape(5* 32,32), cmap=cm.Greys)
mout.shape
# Out:
# (40, 5120)

# %%
mout.shape
# Out:
# (1, 5120)

# %%
pwd
# Out:
# u'/home/dudevil/prog/dmlabs/NDSB/analysis'
